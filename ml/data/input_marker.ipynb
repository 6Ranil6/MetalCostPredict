# %%
# Создаем выбор input (марка / основная марка) в зависимости от того, что ввел пользователь

# %%
import pandas as pd

df = pd.read_csv('/home/ranil/Рабочий стол/PROJECT/ml/data/preprocessing_result.csv', index_col= 0)
df.head()
# Out:
# /tmp/ipykernel_21858/2537223579.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/ranil/Рабочий стол/PROJECT/ml/data/preprocessing_result.csv', index_col= 0)
#   Наименование ГОСТ Телефон Тип_продукции  Размер_A  Типоразмер Марка  \
# 0  Арматура А1  NaN     NaN         Число      10.0         NaN   NaN
# 1  Арматура А1  NaN     NaN         Число      10.0         NaN   NaN
# 2  Арматура А1  NaN     NaN         Число      10.0         NaN   NaN
# 3  Арматура А1  NaN     NaN         Число       8.0         NaN   NaN
# 4  Арматура А1  NaN     NaN         Число       8.0         NaN   NaN
#
#   Примечание_для_размера  Толщина  Диапазон_min  ...  Тип_материала  \
# 0                    NaN      NaN           NaN  ...          Сталь
# 1                    NaN      NaN           NaN  ...      Не указан
# 2                    NaN      NaN           NaN  ...          Сталь
# ...

# %%
df
# Out:
#       Наименование ГОСТ Телефон     Тип_продукции  Размер_A  Типоразмер Марка  \
# 0      Арматура А1  NaN     NaN             Число      10.0         NaN   NaN
# 1      Арматура А1  NaN     NaN             Число      10.0         NaN   NaN
# 2      Арматура А1  NaN     NaN             Число      10.0         NaN   NaN
# 3      Арматура А1  NaN     NaN             Число       8.0         NaN   NaN
# 4      Арматура А1  NaN     NaN             Число       8.0         NaN   NaN
# ...            ...  ...     ...               ...       ...         ...   ...
# 73533         Шина  NaN     NaN  Профиль ГОСТ/СТО       NaN         6.0   Х35
# 73534         Шина  NaN     NaN  Профиль ГОСТ/СТО       NaN         8.0   Х50
# 73535         Шина  NaN     NaN  Профиль ГОСТ/СТО       NaN         3.0   Х15
# 73536         Шина  NaN     NaN  Профиль ГОСТ/СТО       NaN         3.0   Х20
# 73537         Шина  NaN     NaN           Габарит      12.5         NaN   NaN
#
# ...
